# %% [markdown]
# # YOLOv8 Custom DataSet Train

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt") #yolov8m.pt has given the best performance till now

# %%
model.train(data = "data.yaml", epochs = 5) #Fine tuning
# Out:
# New https://pypi.org/project/ultralytics/8.2.36 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.35  Python-3.12.3 torch-2.3.1+cpu CPU (AMD Ryzen 7 6800HS with Radeon Graphics)
# ...

# %%
infer = YOLO("C:/Users/nadil/Desktop/Xfly-Image-Localization/runs/detect/train3/weights/best.pt")

# %%
infer.predict("C:/Users/nadil/Desktop/Xfly-Image-Localization/Heli/val/images", save=True, save_txt=True)
# Out:
# image 1/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (1).jpg: 448x640 (no detections), 125.8ms
# image 2/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (10).jpg: 480x640 (no detections), 114.8ms
# image 3/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (11).jpg: 480x640 (no detections), 111.8ms
# image 4/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (12).jpg: 480x640 (no detections), 110.8ms
# image 5/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (13).jpg: 480x640 (no detections), 112.0ms
# image 6/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (14).jpg: 448x640 (no detections), 111.3ms
# image 7/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (15).jpg: 448x640 (no detections), 104.8ms
# image 8/31 C:\Users\nadil\Desktop\Xfly-Image-Localization\Heli\val\images\img (16).jpg: 480x640 (no detections), 112.8ms
# ...
